# %%
import pickle
import pandas as pd
import numpy as np
import requests
import base64

client_id = 'ca83153c363a4fbc8fc683647b84831d'
client_secret = '2aa45112fa0e4d38befc0cbde25006e1'

# %%
def get_service_token():
    access_token = None
    form = {
        'grant_type': 'client_credentials'
    }
    auth_str = f'{client_id}:{client_secret}'
    headers = {
        'Authorization': 'Basic '+str(base64.b64encode(bytes(auth_str,'utf-8')), "utf-8")
    }
    r = requests.post('https://accounts.spotify.com/api/token', data=form, headers=headers)
    if r.status_code == 200:
        access_token = r.json()['access_token']
    
    return access_token

# %%
def get_tracks(playlist_id, headers, next_url=None, track_list={}):
    if next_url:
        rtracks = requests.get(next_url, headers=headers)
    else:
        rtracks = requests.get(f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks', headers=headers)
        
    tracks = rtracks.json()
    for track in tracks['items']:
        if track['track']['id']:
            track_list[track['track']['id']] = {
                '_id': track['track']['id'],
                'name': track['track']['name'],
                'duration_ms': track['track']['duration_ms'],
                'popularity': track['track']['popularity'],
                'explicit': track['track']['explicit'],
                'artist': track['track']['artists'][0]['name']
            }

    if tracks['next']:
        return get_tracks(playlist_id, headers, next_url=tracks['next'], track_list=track_list)
    else:
        return track_list

def get_track_data(track_list, headers, iter_index=0):
    id_list = list(track_list.keys())
    start_index = iter_index*50
    end_index = (iter_index+1)*50 if (iter_index+1)*50 < len(id_list) else len(id_list)
    req_id_list = id_list[start_index:end_index]

    rdata = requests.get(f'https://api.spotify.com/v1/tracks/?ids={",".join(req_id_list)}', headers=headers)
    data = rdata.json()
    for track in data['tracks']:
        track_list[track['id']]['release_date'] = track['album']['release_date']

    if end_index != len(id_list):
        iter_index += 1
        return get_track_data(track_list, headers, iter_index=iter_index)
    else:
        return track_list


def get_track_features(track_list, headers, iter_index=0):
    id_list = list(track_list.keys())
    start_index = iter_index*100
    end_index = (iter_index+1)*100 if (iter_index+1)*100 < len(id_list) else len(id_list)
    req_id_list = id_list[start_index:end_index]

    rfeatures = requests.get(f'https://api.spotify.com/v1/audio-features/?ids={",".join(req_id_list)}', headers=headers)
    features = rfeatures.json()

    for feature in features['audio_features']:
        track_list[feature['id']]['danceability'] = feature['danceability']
        track_list[feature['id']]['energy'] = feature['energy']
        track_list[feature['id']]['key'] = feature['key']
        track_list[feature['id']]['loudness'] = feature['loudness']
        track_list[feature['id']]['mode'] = feature['mode']
        track_list[feature['id']]['speechiness'] = feature['speechiness']
        track_list[feature['id']]['acousticness'] = feature['acousticness']
        track_list[feature['id']]['instrumentalness'] = feature['instrumentalness']
        track_list[feature['id']]['liveness'] = feature['liveness']
        track_list[feature['id']]['valence'] = feature['valence']
        track_list[feature['id']]['tempo'] = feature['tempo']
        track_list[feature['id']]['time_signature'] = feature['time_signature']

    if end_index != len(id_list):
        iter_index += 1
        return get_track_features(track_list, headers, iter_index=iter_index)
    else:
        return track_list


def get_audio_feature(track_list, headers):
    for track_id in track_list:
        track = track_list[track_id]
        rfeature = requests.get(f'https://api.spotify.com/v1/audio-analysis/{track_id}', headers=headers)
        feature = rfeature.json()
        if 'track' in feature:
            afeature = feature['track']
            segments = feature['segments']

            duration = afeature['duration']
            pitch_values = {'C': 0, 'C#':0, 'D':0, 'D#':0, 'E':0 , 'F':0, 'F#':0, 'G':0, 'G#':0, 'A':0, 'A#':0, 'B':0}
            timbre_values = {'B1': 0, 'B2':0, 'B3':0, 'B4':0, 'B5':0 , 'B6':0, 'B7':0, 'B8':0, 'B9':0, 'B10':0, 'B11':0, 'B12':0}

            for segment in segments:
                seg_duration = segment['duration']
                pitches = segment['pitches']
                pitch_values['C'] += pitches[0] * seg_duration
                pitch_values['C#'] += pitches[1] * seg_duration
                pitch_values['D'] += pitches[2] * seg_duration
                pitch_values['D#'] += pitches[3] * seg_duration
                pitch_values['E'] += pitches[4] * seg_duration
                pitch_values['F'] += pitches[5] * seg_duration
                pitch_values['F#'] += pitches[6] * seg_duration
                pitch_values['G'] += pitches[7] * seg_duration
                pitch_values['G#'] += pitches[8] * seg_duration
                pitch_values['A'] += pitches[9] * seg_duration
                pitch_values['A#'] += pitches[10] * seg_duration
                pitch_values['B'] += pitches[11] * seg_duration

                timbres = segment['timbre']
                timbre_values['B1'] += timbres[0] * seg_duration
                timbre_values['B2'] += timbres[1] * seg_duration
                timbre_values['B3'] += timbres[2] * seg_duration
                timbre_values['B4'] += timbres[3] * seg_duration
                timbre_values['B5'] += timbres[4] * seg_duration
                timbre_values['B6'] += timbres[5] * seg_duration
                timbre_values['B7'] += timbres[6] * seg_duration
                timbre_values['B8'] += timbres[7] * seg_duration
                timbre_values['B9'] += timbres[8] * seg_duration
                timbre_values['B10'] += timbres[9] * seg_duration
                timbre_values['B11'] += timbres[10] * seg_duration
                timbre_values['B12'] += timbres[11] * seg_duration
                

            for note in pitch_values:
                pitch_values[note] = pitch_values[note] / duration

            for basis in timbre_values:
                timbre_values[basis] = timbre_values[basis] / duration

            track['timbre'] = timbre_values
            track['pitches'] = pitch_values
            print(track['name'], 'done.')

    return track_list

# %%
access_token = get_service_token()
headers = {
    'Authorization': 'Bearer ' + access_token
}
track_list = get_tracks('6uDp1IXlSsfqDCJgwaGoEJ', headers, track_list={})
track_list = get_track_data(track_list, headers)
track_list = get_track_features(track_list, headers)
track_list = get_audio_feature(track_list, headers)
track_data = list(track_list.values())
# Out:
# All Night done.
# Talia done.
# bellyache done.
# Better in My Head done.
# Better - SG Lewis x Clairo done.
# Closer done.
# Tokyo done.
# Die For You done.
# All over You done.
# Poison done.
# Dear to Me done.
# Tokyo Lane done.
# Livid done.
# Show Me How done.
# Aftertaste (feat. Opia) done.
# Nightmares done.
# Screenplay done.
# Get You (feat. Kali Uchis) done.
# Alone & Unafraid done.
# Pack of Gum done.
# Bedroom done.
# I Said done.
# Flaws done.
# Work This Out done.
# Blackberries done.
# Hello? done.
# B.O.M.D. done.
# 4EVER done.
# Flaming Hot Cheetos done.
# High Horse done.
# Alaska - Sofi Tukker Remix done.
# You done.
# Fantasize done.
# love is so hard! done.
# Billy done.
# Falling done.
# Hopes Up done.
# Skin done.
# Stranger done.
# Sad Girl done.
# Close done.
# Teardrops done.
# Crime done.
# Summertime Magic done.
# Give A Little done.
# Leaves (Reboot) done.
# Drowning done.
# Drown done.
# Call On Me done.
# Convex done.
# O.M.G. (I'm All Over It) done.
# Never Yours done.
# I Go Crazy done.
# GotItBad done.
# Masterpiece done.
# Perspective done.
# Sweet Dreams done.
# Give In done.
# Feels Good done.
# I'm A Kid done.
# Let Go done.
# Heaven done.
# Cold Call Lover done.
# Like This done.
# Mr. Invisible done.
# September Fades done.
# Long Distance Lover done.
# Tables Have Turned done.
# Italo Disco done.
# I Think I'm Normal done.
# Yung Love done.
# Awake and Pretty Much Sober done.
# Honey done.
# TEST DRIVE done.
# Motion done.
# Better done.
# Smoke done.
# She Ain't Tell Ya done.
# Drip done.
# Be Real done.
# Someone Like You done.
# Cereal done.
# king done.
# Shimmer done.
# Just a Phase done.
# a lot done.
# Saturday Hymnal / Bad Dreams done.
# Make You Wait done.
# Fool Me done.
# Dancing With A Stranger (with Normani) done.
# YEAH RIGHT done.
# Caged Bird done.
# Overnight done.
# The Knife done.
# Say It done.
# Retrograde done.
# Up With the Birdies done.
# Parting Flowers done.
# Venice done.
# Bombae Lemonade done.
# Dog Years done.
# My Favorite Fish done.
# SOBER done.
# stop and stare done.
# Just Be Friends done.
# Rachel done.
# You've Got Your Whole Life Ahead Of You Baby done.
# ur so pretty done.
# We Talk all the Time done.
# Long Lost Sunday Morning done.
# Talk done.
# Matter of Time done.
# Commitment done.
# Neon done.
# lost cause// done.
# Pink Sand done.
# I Have Lost My Pearls done.
# Ditch done.
# Goodie Bag done.
# Habit done.
# Gum, Toe and Sole done.
# California Tears done.
# Slow Down done.
# Maybe You're the Reason done.
# Follow My Girl done.
# affection done.
# better friends done.
# Roaming done.
# still feel. done.
# Coping (Get Over) done.
# Smile done.
# wish you were gay done.
# bury a friend done.
# Money Lover done.
# Narcissist done.
# Matter over Mind done.
# Ooh Wee done.
# Juice done.
# Fill Me Up Anthem done.
# Throwaway done.
# My Bad done.
# Why iii Love The Moon. done.
# Statue Of Liberty. done.
# Before You Get a Boyfriend. done.
# Eastriverstatepark done.
# Holding On done.
# Origami Lover done.
# bad guy done.
# all the good girls go to hell done.
# my strange addiction done.
# ilomilo done.
# Self done.
# Up 2 U done.
# Greensmoke done.
# I'm Just Snacking done.
# Paradise done.
# Dizzy done.
# Lava done.
# Bad Luck done.
# Paradise done.
# Outta My Head (with John Mayer) done.
# Crazy done.
# Dead done.
# Sahara done.
# WASTE MY TIME done.
# Verdigris done.
# Nomadicon done.
# Coax & Botany done.
# Sockboy done.
# Roadhead done.
# Sunshine & Lust Are No Longer Enough done.
# Tremblin' done.
# Running done.
# Pretty Love done.
# Everytime done.
# Only One done.
# Headlights done.
# Lucid done.
# THE BOTTOM done.
# Hard to Move done.
# Kimmi done.
# Orange Girl done.
# Alone Together done.
# My Man done.
# Let Me Go done.
# Pass The Hours done.
# Six Missed Calls done.
# My Love done.
# Breeze done.
# Pool done.
# Giver done.
# Strawberry done.
# Forget About It done.
# Due Girl done.
# Peachsun done.
# Magic Hour done.
# MI done.
# Simple Love done.
# When Am I Gonna Lose You done.
# Bonsai. done.
# Rolex, the Ocean done.
# Let It Pass done.
# Chinatown done.
# BALDWIN done.
# ...baby one more time done.
# My Dude done.
# Strawberry Shortcake done.
# Magic Loop done.
# I Like U done.
# After Life done.
# Bae Caught Me Vapin' done.
# Scrimmage done.
# double take done.
# UNI done.
# Hey done.
# Sanctuary done.
# Useless Phrases done.
# Cheap Queen done.
# Bodiez done.
# Dreamz done.
# Call It Home done.
# Don't Leave Me Behind done.
# Discover Each Other done.
# Loverboy done.
# Ride done.
# Blue done.
# Overdose (with HONNE) done.
# Flames (feat. Ruel) done.
# Easy Loving You (with Kamille) done.
# Pieces of Us (feat. King Princess) done.
# Fall In Love done.
# Slip done.
# Sun done.
#  done.
# DYSFUNCTIONAL done.
# Closer To You done.
# OPEN UP done.
# SUPERPOSITION done.
# Distant done.
# george done.
# Te extraño, pero... done.
# Time done.
# Dive Deep done.
# Fantasy done.
# I Bet done.
# Alcohol & Misery done.
# Silk done.
# No Secrets done.
# wannabe done.
# Miracle Love done.
# Wild Roses done.
# pharmacy done.
# woman on the hills done.
# Nervous done.
# Antidote done.
# Meet Me in the City done.
# Passionfruit done.
# Catch a Feeling done.
# youth done.
# Prophet done.
# Say It done.
# Ridin' with You done.
# drinking games done.
# Brat done.
# B Cool (feat. Melanie Faye) done.
# Róróró done.
# Vulture, Vulture done.
# Caught Up (feat. Khalid) done.
# For a Summer done.
# Typical done.
# Tha Steeze done.
# Say All the Right Things done.
# CARLO done.
# Heartbeat done.
# Sober done.
# Impossible done.
# Softly done.
# Feel Something done.
# CULPRIT done.
# Follow Suit done.
# Circles done.
# Was It Something I Said done.
# Foolsong done.
# Hold Up done.
# Sauce done.
# Waste My Time done.
# Playground done.
# Twenties done.
# 9th Street done.
# Helmet done.
# TURBO DREAMS done.
# the stage done.
# forever done.
# Touch done.
# Tongue Tied done.
# 2Shy done.
# Waitin' for You done.
# Same Old done.
# SUGAR done.
# Rufufus done.
# Water Me done.
# Wyd done.
# Friendzone done.
# Thank Me Later done.
# Ford Cardinal done.
# Feels done.
# 1998 done.
# CLOUD done.
# OUTTA MY MIND done.
# Queens & Kings done.
# Call My Name done.
# Thickness done.
# Even If It Hurts (feat. Blood Orange) done.
# Feelings in Me done.
# Price Went Up done.
# Chlorine done.
# Say It's Fine done.
# Need Is Your Love done.
# Obsessed done.
# On My Mind done.
# Pressure (with SG Lewis) done.
# 1 4 Me done.
# 24-7 done.
# Time To Get Over It done.
# Melodramatic done.
# Killshot done.
# Venice done.
# Plane Ride done.
# Show Me Love (feat. 21 Savage & Miguel) done.
# Gimme Gimme done.
# Bad Behavior done.
# Addict done.
# Game done.
# Lava/Treacle done.
# Heaven done.
# not gonna lie... done.
# Heartless done.
# I Don't Like You done.
# Faceless done.
# Lara (feat. Clairo) done.
# Nine One One done.
# Tear It Apart (with Kenny Beats) done.
# Let Me In done.
# GoneGirl done.
# Scream done.
# Give It Up done.
# Another Love done.
# dancefloor done.
# High School done.
# Sink into the Floor done.
# I Can't Sleep done.
# I Could Never Be Loved done.
# Would Look Perfect done.
# The Story of the Paper Boy done.
# By the Poolside done.
# Eleven done.
# 4am done.
# Morning done.
# Stuck done.
# Let Me done.
# Laying on my porch while we watch the world end. done.
# How To Forgive done.
# Are You Okay? done.
# Sunrise done.
# Castaway done.
# Henny in the Hamptons done.
# Nothing To Lose done.
# Know Your Worth done.
# Run done.
# Heartbeat done.
# hoodie done.
# Hoodie Strings done.
# Crack a Deal done.
# Hell of a Ride done.
# Sweet Talk done.
# Medallion done.
# Fall 4 You done.
# After Hours done.
# Wishful Thinking done.
# Someone New done.
# Growing Up done.
# Best of Me done.
# Moon done.
# Into Me done.
# SUGAR (Remix) [feat. Dua Lipa] done.
# Hold It Together done.
# Unchained done.
# Dice Out done.
# Dirty done.
# Cover Under Comfort done.
# One, Two done.
# It's Alright done.
# Replay done.
# Not My Baby done.
# In Your Eyes done.
# Guy done.
# Gimme Love done.
# death bed (coffee for your head) done.
# First Aid done.
# Better Half done.
# good guys done.
# Turn Me On (Live From London) done.
# Perfect Company (Live From London) done.
# Disco Man done.
# Memories done.
# Under Control done.
# No Drug Like Me done.
# Something to Rap About (feat. Tyler, The Creator) done.
# Faith done.
# Superficial Love done.
# Automatic Driver - Tyler, The Creator Remix done.
# EARFQUAKE done.
# Woo! done.
# Photo ID done.
# Greed done.
# Baby Powder done.
# Right Words Wrong Time done.
# First Bloom done.
# Little Bit done.
# No Más! done.
# Time done.
# Holding Me done.
# Moon done.
# Crush done.
# Edamame done.
# What Do You Like In Me done.
# No Compromise done.
# Can't Fight done.
# Please Don't Make Me Cry done.
# Smithereens done.
# THINK ABOUT ME done.
# In My Head done.
# Sweet (feat. Landon Sears) done.
# Love Affair done.
# Stayback done.
# Daylight done.
# So Damn Fly done.
# Stay done.
# 7PM done.
# Lighter done.
# Selene done.
# Return of the Mack done.
# Say It. done.
# Omw done.
# Over Now (with The Weeknd) done.
# Good Thing (with Kehlani) done.
# Coffee Bean done.
# Like YOU done.
# Medicine done.
# Wait done.
# hello! done.
# My Say So done.
# You Are the Traffic done.
# Softly done.
# Ew done.
# Pretty Boy (feat. Lil Yachty) done.
# Normal People (feat. rei brown) done.
# MODUS done.
# Afterthought done.
# Mr. Hollywood done.
# NITROUS done.
# 777 done.
# Soaked done.
# Y U Always Acting Like a Fool? done.
# Come Over (feat. Popcaan) done.
# Lock N Key done.
# Ride done.
# Say So done.
# They Don't Know done.
# Plain (feat. Lily Allen & Flo Milli) done.
# Portals done.
# Somebody Else done.
# Be Here Soon done.
# HEARTBREAKER done.
# CAN YOU FEEL IT done.
# BLOCK SCHOLARS done.
# Therefore I Am done.

# %%
track_df_master = pd.DataFrame(track_data)
track_df_master.set_index('_id', inplace=True)

track_df = track_df_master.copy()

track_df.drop("name", axis=1, inplace=True)
track_df.drop("artist", axis=1, inplace=True)
track_df.drop("explicit", axis=1, inplace=True)
track_df.drop("duration_ms", axis=1, inplace=True)
track_df.drop("time_signature", axis=1, inplace=True)
track_df.drop("mode", axis=1, inplace=True)
track_df.drop("key", axis=1, inplace=True)
track_df['release_date'] = pd.to_numeric(track_df['release_date'].str.split('-',expand=True)[1])
track_df["release_date"].fillna(track_df["release_date"].median(skipna=True), inplace=True)
track_df.drop("pitches", axis=1, inplace=True)
track_df.drop("timbre", axis=1, inplace=True)

tone_model = pickle.load(open('tone.model','rb'))
tone_X = track_df.copy()
tone = tone_model.predict(tone_X)
track_df['tone'] = tone
hot_track = track_df[track_df['tone'] == 0]
cold_track = track_df[track_df['tone'] == 1]

hot_track_X = hot_track.drop(['tone'], axis=1)
hot_model = pickle.load(open('spring_summer.model','rb'))
season = hot_model.predict(hot_track_X)
hot_track_X['season'] = season
hot_track_X['season'] = hot_track_X['season'].replace(0, 'spring')
hot_track_X['season'] = hot_track_X['season'].replace(1, 'summer')

cold_track_X = cold_track.drop(['tone'], axis=1)
cold_model = pickle.load(open('winter_autumn.model','rb'))
season = cold_model.predict(cold_track_X)
cold_track_X['season'] = season
cold_track_X['season'] = cold_track_X['season'].replace(0, 'autumn')
cold_track_X['season'] = cold_track_X['season'].replace(1, 'rainy')
cold_track_X['season'] = cold_track_X['season'].replace(2, 'winter')

season_sr = cold_track_X['season'].append(hot_track_X['season'])
track_df = pd.merge(track_df, season_sr, left_index=True, right_index=True, how='left')

# %%
pitch_keys = ['C','C#','D', 'D#', 'E' , 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
timbre_keys = ['B1', 'B2', 'B3', 'B4', 'B5' , 'B6', 'B7', 'B8', 'B9', 'B10', 'B11', 'B12']

track_df['pitches'] = track_df_master['pitches']
track_df['timbre'] = track_df_master['timbre']

track_df = pd.concat([track_df, track_df['pitches'].apply(pd.Series)], axis=1)
track_df = pd.concat([track_df, track_df['timbre'].apply(pd.Series)], axis=1)
if 0 in track_df.columns:
    track_df.drop(0, axis=1, inplace=True)
for pitch in pitch_keys:
    track_df[pitch].fillna(track_df[pitch].median(skipna=True), inplace=True)

for timbre in timbre_keys:
    track_df[timbre].fillna(track_df[timbre].median(skipna=True), inplace=True)

track_df.drop("timbre", axis=1, inplace=True)
track_df.drop("pitches", axis=1, inplace=True)

emotion_model = pickle.load(open('emotion.model','rb'))
emotion_X = track_df.drop(['tone', 'season'], axis=1)
emotion = emotion_model.predict(emotion_X)
track_df['emotion'] = emotion
track_df['emotion'] = track_df['emotion'].replace(0, 'chill')
track_df['emotion'] = track_df['emotion'].replace(1, 'happy')
track_df['emotion'] = track_df['emotion'].replace(2, 'party')
track_df['emotion'] = track_df['emotion'].replace(3, 'sad')
track_df['emotion'].value_counts()
# Out:
# chill    360
# sad       57
# party     33
# happy     27
# Name: emotion, dtype: int64

# %%
from kmodes.kmodes import KModes

for n in range(20,1,-1):
    km_cao = KModes(n_clusters=n, init = "Huang", n_init=10)
    clusters = km_cao.fit_predict(track_df[['emotion','season']])
    min_track_count = pd.Series(clusters).value_counts().min()
    if min_track_count > 9:
        break

track_df['cluster'] = clusters

# %%
# print(track_df[track_df['cluster']==0]['season'].value_counts())
# print(track_df[track_df['cluster']==0]['emotion'].value_counts())
season_playlist_name = {
    ('summer',): 'Summer',
    ('spring',): 'Spring',
    ('autumn',): 'Autumn',
    ('winter',): 'Winter',
    ('rainy',): 'Rainy',
    ('spring','summer'): 'Sunny',
    ('autumn','summer'): 'Vividly',
    ('summer','winter'): 'Melty',
    ('rainy','summer'): 'Sultry',
    ('autumn','spring'): 'Peaceful',
    ('spring','winter'): 'Snowy',
    ('rainy','spring'): 'Cloudy',
    ('autumn','winter'): 'Windy',
    ('autumn','rainy'): 'Dampy',
    ('rainy','winter'): 'Freezy'
}

emotion_playlist_name = {
    ('happy',): 'Happiness',
    ('chill',): 'Chill',
    ('party',): 'Party',
    ('sad',): 'Sadness',
    ('chill','happy'): 'Comfort',
    ('happy','party'): 'Fun',
    ('happy','sad'): 'Confusion',
    ('chill','party'): 'Rhythm',
    ('party','sad'): 'Conflict',
    ('chill','sad'): 'Melancholy'
}

clustered_playlist = {}
for i in range(n):
    cluster = track_df[track_df['cluster']==i]
    cluster['id'] = cluster.index
    cluster = pd.merge(cluster, track_df_master[['name','artist']], left_index=True, right_index=True, how='left')
    season_char = None
    emotion_char = None
    season_rank = cluster['season'].value_counts().sort_values(ascending=False)
    emotion_rank = cluster['emotion'].value_counts().sort_values(ascending=False)
    size = cluster.shape[0]
    season_char = (season_rank.index[0],)
    if season_rank.size > 1 and (season_rank[1]/size) > (season_rank[0]/size/2):
        season_char = (season_rank.index[0], season_rank.index[1])

    emotion_char = (emotion_rank.index[0],)
    if emotion_rank.size > 1 and (emotion_rank[1]/size) > (emotion_rank[0]/size/2):
        emotion_char = (emotion_rank.index[0], emotion_rank.index[1])

    clustered_playlist[i] = {
        'name': season_playlist_name[tuple(sorted(season_char))] + " " + emotion_playlist_name[tuple(sorted(emotion_char))],
        'tracks': cluster[['name','artist','season','emotion','id']].to_dict(orient='records')
    }
    print(clustered_playlist[i]['name'])
    print(season_rank)
    print(emotion_rank)
    print('='*20)
    test_list = cluster['id']

test_list
# Out:
# Winter Sadness
# winter    24
# autumn     6
# spring     2
# summer     2
# Name: season, dtype: int64
# sad      28
# happy     4
# party     2
# Name: emotion, dtype: int64
# ====================
# Winter Chill
# winter    88
# autumn    23
# Name: season, dtype: int64
# chill    111
# Name: emotion, dtype: int64
# ====================
# Spring Chill
# spring    105
# Name: season, dtype: int64
# chill    99
# happy     6
# Name: emotion, dtype: int64
# ====================
# Rainy Sadness
# rainy    36
# Name: season, dtype: int64
# sad      29
# happy     6
# party     1
# Name: emotion, dtype: int64
# ====================
# Vividly Happiness
# autumn    9
# summer    5
# Name: season, dtype: int64
# happy    11
# party     3
# Name: emotion, dtype: int64
# ====================
# Summer Chill
# summer    67
# Name: season, dtype: int64
# chill    67
# Name: emotion, dtype: int64
# ====================
# Spring Party
# spring    14
# Name: season, dtype: int64
# party    14
# Name: emotion, dtype: int64
# ====================
# Rainy Chill
# rainy    83
# Name: season, dtype: int64
# chill    83
# Name: emotion, dtype: int64
# ====================
# Summer Party
# summer    13
# Name: season, dtype: int64
# party    13
# Name: emotion, dtype: int64
# ====================
# _id
# 4WctYxntPchMNURUL7npao    4WctYxntPchMNURUL7npao
# 0Pf1u3VenZZcGo3KMy1kXP    0Pf1u3VenZZcGo3KMy1kXP
# 5HxOb9uuXWpf7AICL8Nk0o    5HxOb9uuXWpf7AICL8Nk0o
# 0nkgDTXNZEuUZ7Jt42itVa    0nkgDTXNZEuUZ7Jt42itVa
# 5gWMhSFunyD3WmH1lrPzWM    5gWMhSFunyD3WmH1lrPzWM
# 1qGgODF8DbvKd6X3faxtfN    1qGgODF8DbvKd6X3faxtfN
# 5gZs8c7CzucKcMCUXVVQIj    5gZs8c7CzucKcMCUXVVQIj
# 79ymkcgT5EvrtsraYdgbco    79ymkcgT5EvrtsraYdgbco
# 7szuecWAPwGoV1e5vGu8tl    7szuecWAPwGoV1e5vGu8tl
# 0bhciG1J5Mn3aIfPjvHQIe    0bhciG1J5Mn3aIfPjvHQIe
# 3bjfVBezMzhzI6I9irA5Ra    3bjfVBezMzhzI6I9irA5Ra
# 3jDdpx9PMlfMBS5tOBHFm9    3jDdpx9PMlfMBS5tOBHFm9
# 58mtgcQVZ56NgWHKsN94nD    58mtgcQVZ56NgWHKsN94nD
# Name: id, dtype: object
